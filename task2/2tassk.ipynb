# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ls "/content/drive/MyDrive/Github/Brainwave_Matrix_Intern"
# Out:
# README.md  task1

# %%
import os

# Path where you want to create the folder
folder_path = "/content/drive/MyDrive/Github/Brainwave_Matrix_Intern/task 2"

# Create folder if it doesn't exist
os.makedirs(folder_path, exist_ok=True)

print("Folder 'task 2' created (or already existed) inside Brainwave_Matrix_Intern")
# Out:
# Folder 'task 2' created (or already existed) inside Brainwave_Matrix_Intern

# %%
# !ls "/content/drive/MyDrive/Github/Brainwave_Matrix_Intern"
# Out:
#  README.md   task1  'task 2'

# %%
import shutil

source = "/content/drive/MyDrive/Colab Notebooks/2tassk.ipynb"   # note the double 's'
destination = "/content/drive/MyDrive/Github/Brainwave_Matrix_Intern/task 2/2tassk.ipynb"

shutil.move(source, destination)

print("File moved successfully!")
# Out:
# File moved successfully!

# %%
# !ls "/content/drive/MyDrive/Github/Brainwave_Matrix_Intern/task 2"
# Out:
# 2tassk.ipynb

# %%
mv "/content/drive/MyDrive/Github/Brainwave_Matrix_Intern/task 2/2tassk.ipynb" "task 2/"
# Out:
# mv: cannot create regular file 'task 2/': Not a directory
